# %% [markdown]
# #Configure Access to Cloud Storage via Unity Catalog

# %% [markdown]
# **Access Cloud Storage**

# %%
display(dbutils.fs.ls('abfss://formula1-raw@formula1dlharris.dfs.core.windows.net/'))

# %% [markdown]
# **Create External Location**

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS formula1dlharris
URL 'abfss://formula1-raw@formula1dlharris.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `formula1dlharris_azuremanagedidentity_1782060661052`)
COMMENT 'External location for formula1 raw container';
